# %% [markdown]
# <a href="https://colab.research.google.com/github/kratikay25/APS/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous_nodes = {node: None for node in graph}
    visited = []

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous_nodes[neighbor] = min_node

    return distances, previous_nodes


def shortest_path(previous_nodes, start, target):
    path = []
    current = target
    while current is not None:
        path.insert(0, current)
        current = previous_nodes[current]
    if path[0] == start:
        return path
    else:
        return None

# User input for source node
start_node = input("Enter the source node: ").strip().upper()

distances, previous_nodes = dijkstra(graph, start_node)

print("\nShortest paths from node", start_node)
for target in graph:
    path = shortest_path(previous_nodes, start_node, target)
    if path:
        print(f"{start_node} → {target}: Path = {' -> '.join(path)}, Distance = {distances[target]}")
    else:
        print(f"{start_node} → {target}: No path found")
# Out:
# Enter the source node: c
#
# Shortest paths from node C
# C → A: Path = C -> B -> A, Distance = 3
# C → B: Path = C -> B, Distance = 1
# C → C: Path = C, Distance = 0
# C → D: Path = C -> D, Distance = 3
# C → E: Path = C -> E, Distance = 5
# C → F: Path = C -> D -> F, Distance = 4

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous_nodes = {node: None for node in graph}
    visited = []

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous_nodes[neighbor] = min_node

    return distances, previous_nodes


def shortest_path(previous_nodes, start, target):
    path = []
    current = target
    while current is not None:
        path.insert(0, current)
        current = previous_nodes[current]
    if path[0] == start:
        return path
    else:
        return None


# --- User Input Graph ---
print("Enter edges in format: Node1 Node2 Weight")
print("Type 'done' when finished.\n")

graph = {}

while True:
    entry = input("Edge: ").strip()
    if entry.lower() == "done":
        break
    try:
        node1, node2, weight = entry.split()
        weight = int(weight)

        if node1 not in graph:
            graph[node1] = {}
        if node2 not in graph:
            graph[node2] = {}

        graph[node1][node2] = weight
        graph[node2][node1] = weight  # undirected graph
    except:
        print("Invalid format. Use: Node1 Node2 Weight")

# --- Add two more nodes ---
graph['E'] = {'C': 5, 'D': 2, 'F': 3}
graph['F'] = {'D': 1, 'E': 3}

# --- Test with different source nodes ---
while True:
    start_node = input("\nEnter source node (or 'exit' to quit): ").strip().upper()
    if start_node.lower() == "exit":
        break
    if start_node not in graph:
        print("Node not found in graph.")
        continue

    distances, previous_nodes = dijkstra(graph, start_node)

    print(f"\nShortest paths from node {start_node}:")
    for target in graph:
        path = shortest_path(previous_nodes, start_node, target)
        if path:
            print(f"{start_node} → {target}: Path = {' -> '.join(path)}, Distance = {distances[target]}")
        else:
            print(f"{start_node} → {target}: No path found")
# Out:
# Enter edges in format: Node1 Node2 Weight
# Type 'done' when finished.
#
# Edge:  A B 1
# Edge: B C 3
# Edge: A D 5
# Edge: done
#
# Enter source node (or 'exit' to quit): A
#
# Shortest paths from node A:
# A → A: Path = A, Distance = 0
# A → B: Path = A -> B, Distance = 1
# A → C: Path = A -> B -> C, Distance = 4
# A → D: Path = A -> D, Distance = 5
# A → E: No path found
# A → F: No path found
#
# Enter source node (or 'exit' to quit): A
#
# Shortest paths from node A:
# A → A: Path = A, Distance = 0
# A → B: Path = A -> B, Distance = 1
# A → C: Path = A -> B -> C, Distance = 4
# A → D: Path = A -> D, Distance = 5
# A → E: No path found
# A → F: No path found
#
# Enter source node (or 'exit' to quit): B
#
# Shortest paths from node B:
# B → A: Path = B -> A, Distance = 1
# B → B: Path = B, Distance = 0
# B → C: Path = B -> C, Distance = 3
# B → D: Path = B -> A -> D, Distance = 6
# B → E: No path found
# B → F: No path found
#
# Enter source node (or 'exit' to quit): C
#
# Shortest paths from node C:
# C → A: Path = C -> B -> A, Distance = 4
# C → B: Path = C -> B, Distance = 3
# C → C: Path = C, Distance = 0
# C → D: Path = C -> B -> A -> D, Distance = 9
# C → E: No path found
# C → F: No path found
#
# Enter source node (or 'exit' to quit): D
#
# Shortest paths from node D:
# D → A: Path = D -> A, Distance = 5
# D → B: Path = D -> A -> B, Distance = 6
# D → C: Path = D -> A -> B -> C, Distance = 9
# D → D: Path = D, Distance = 0
# D → E: No path found
# D → F: No path found
#
# Enter source node (or 'exit' to quit): exit
